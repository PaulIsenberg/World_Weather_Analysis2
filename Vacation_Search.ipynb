# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key
import traceback

# %%
vacation_cities_df = pd.read_csv("weather_data/WeatherPy_challenge.csv")
vacation_cities_df.head()
# Out:
#    City_ID          City Country                 Date    Lat    Lng  Max Temp  \
# 0        0  Longyearbyen      SJ  2020-04-19 00:00:11  78.22  15.64     28.40
# 1        1    Bredasdorp      ZA  2020-04-18 23:57:12 -34.53  20.04     50.00
# 2        2        Sabang      ID  2020-04-19 00:00:50   5.89  95.32     82.45
# 3        3  Richards Bay      ZA  2020-04-19 00:00:50 -28.78  32.04     72.46
# 4        4     Ilulissat      GL  2020-04-18 23:57:44  69.22 -51.10     23.00
#
#    Humidity  Cloudiness  Wind Speed Current Description  \
# 0        92          20        2.24          few clouds
# 1        87          55        2.24       broken clouds
# 2        72          83        3.36       broken clouds
# 3        79          40        8.46          light rain
# 4        85         100        8.05     overcast clouds
#
#    Rain inches (last 3 hrs)  Snow inches (last 3 hrs)
# 0                      0.00                       0.0
# ...

# %%
vacation_cities_df.dtypes
# Out:
# City_ID                       int64
# City                         object
# Country                      object
# Date                         object
# Lat                         float64
# Lng                         float64
# Max Temp                    float64
# Humidity                      int64
# Cloudiness                    int64
# Wind Speed                  float64
# Current Description          object
# Rain inches (last 3 hrs)    float64
# Snow inches (last 3 hrs)    float64
# dtype: object

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
rain_cities = vacation_cities_df.loc[vacation_cities_df["Rain inches (last 3 hrs)"]>0]
snow_cities = vacation_cities_df.loc[vacation_cities_df["Snow inches (last 3 hrs)"]>0]

# %%
snow_cities
# Out:
#      City_ID         City Country                 Date    Lat     Lng  \
# 132      132      Paamiut      GL  2020-04-19 00:00:57  61.99  -49.67
# 160      160  Provideniya      RU  2020-04-19 00:00:55  64.38 -173.30
# 191      191    Nadvoitsy      RU  2020-04-19 00:01:00  63.87   34.32
# 209      209        Aldan      RU  2020-04-18 23:56:22  58.60  125.39
# 258      258       Narsaq      GL  2020-04-19 00:01:04  60.92  -46.05
# 264      264   Lavrentiya      RU  2020-04-18 23:57:52  65.58 -171.00
# 273      273   Nanortalik      GL  2020-04-19 00:01:04  60.14  -45.24
# 279      279    Ostrovnoy      RU  2020-04-19 00:01:05  68.05   39.51
# 322      322    Egvekinot      RU  2020-04-18 23:58:47  66.32 -179.17
# 331      331     Qaqortoq      GL  2020-04-19 00:01:08  60.72  -46.03
# 420      420     Chumikan      RU  2020-04-19 00:01:12  54.72  135.31
# 456      456       Hearst      CA  2020-04-19 00:01:14  49.68  -83.67
# ...

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
rain_or_not = str(input("Do you want it to be raining? (yes/no) "))
snow_or_not = str(input("Do you want it to be snowing? (yes/no) "))
# Out:
# What is the minimum temperature you would like for your trip? 25
# What is the maximum temperature you would like for your trip? 55
# Do you want it to be raining? (yes/no) no
# Do you want it to be snowing? (yes/no) no

# %%
#selected_cities = []
#selected_cities_df = pd.DataFrame(vacation_cities_df)


if rain_or_not == "no" and snow_or_not == "no":
        selected_cities = vacation_cities_df.loc[(vacation_cities_df["Max Temp"] <= max_temp) &
                                        (vacation_cities_df["Max Temp"] >= min_temp) &
                                        (vacation_cities_df["Rain inches (last 3 hrs)"] == 0) &
                                        (vacation_cities_df["Snow inches (last 3 hrs)"] == 0)]
elif rain_or_not == "yes" and snow_or_not == "no":
        selected_cities = vacation_cities_df.loc[(vacation_cities_df["Max Temp"] <= max_temp) &
                                        (vacation_cities_df["Max Temp"] >= min_temp) &
                                        (vacation_cities_df["Rain inches (last 3 hrs)"] != 0) &
                                        (vacation_cities_df["Snow inches (last 3 hrs)"] == 0)]
elif rain_or_not == "no" and snow_or_not == "yes":
        selected_cities = vacation_cities_df.loc[(vacation_cities_df["Max Temp"] <= max_temp) &
                                        (vacation_cities_df["Max Temp"] >= min_temp) &
                                        (vacation_cities_df["Rain inches (last 3 hrs)"] == 0) &
                                        (vacation_cities_df["Snow inches (last 3 hrs)"] != 0)]
else:
        selected_cities = vacation_cities_df.loc[(vacation_cities_df["Max Temp"] <= max_temp) &
                                        (vacation_cities_df["Max Temp"] >= min_temp) &
                                        (vacation_cities_df["Rain inches (last 3 hrs)"] != 0) &
                                        (vacation_cities_df["Snow inches (last 3 hrs)"] != 0)]

# %%
selected_cities
# Out:
#      City_ID          City Country                 Date    Lat     Lng  \
# 0          0  Longyearbyen      SJ  2020-04-19 00:00:11  78.22   15.64
# 1          1    Bredasdorp      ZA  2020-04-18 23:57:12 -34.53   20.04
# 12        12       Ushuaia      AR  2020-04-19 00:00:38 -54.80  -68.30
# 14        14        Berdsk      RU  2020-04-19 00:00:50  54.76   83.10
# 18        18   Yellowknife      CA  2020-04-19 00:00:50  62.46 -114.35
# ..       ...           ...     ...                  ...    ...     ...
# 541      541        Kijang      KR  2020-04-19 00:01:19  35.24  129.21
# 542      542      Nevsehir      TR  2020-04-19 00:01:19  38.92   34.67
# 546      546        Iwanai      JP  2020-04-19 00:01:19  42.97  140.51
# 557      557       Wiarton      CA  2020-04-19 00:01:20  44.74  -81.13
# 558      558         Bayir      TR  2020-04-19 00:01:20  37.27   28.22
#
#      Max Temp  Humidity  Cloudiness  Wind Speed Current Description  \
# ...

# %%
selected_cities_df.count()
# Out:
# City_ID                     131
# City                        131
# Country                     131
# Date                        131
# Lat                         131
# Lng                         131
# Max Temp                    131
# Humidity                    131
# Cloudiness                  131
# Wind Speed                  131
# Current Description         131
# Rain inches (last 3 hrs)    131
# Snow inches (last 3 hrs)    131
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = selected_cities_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df
# Out:
#              City Country  Max Temp Current Description    Lat     Lng  \
# 0    Longyearbyen      SJ     28.40          few clouds  78.22   15.64
# 1      Bredasdorp      ZA     50.00       broken clouds -34.53   20.04
# 12        Ushuaia      AR     46.40    scattered clouds -54.80  -68.30
# 14         Berdsk      RU     30.20               smoke  54.76   83.10
# 18    Yellowknife      CA     26.60          light snow  62.46 -114.35
# ..            ...     ...       ...                 ...    ...     ...
# 541        Kijang      KR     53.60       broken clouds  35.24  129.21
# 542      Nevsehir      TR     48.97          few clouds  38.92   34.67
# 546        Iwanai      JP     54.50     overcast clouds  42.97  140.51
# 557       Wiarton      CA     48.99     overcast clouds  44.74  -81.13
# 558         Bayir      TR     51.80           clear sky  37.27   28.22
#
#     Hotel Name
# 0
# 1
# 12
# 14
# 18
# ..         ...
# 541
# 542
# 546
# 557
# 558
#
# [131 rows x 7 columns]

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found....skipping")
# Out:
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping
# Hotel not found....skipping

# %%
hotel_df
# Out:
#              City Country  Max Temp Current Description    Lat     Lng  \
# 0    Longyearbyen      SJ     28.40          few clouds  78.22   15.64
# 1      Bredasdorp      ZA     50.00       broken clouds -34.53   20.04
# 12        Ushuaia      AR     46.40    scattered clouds -54.80  -68.30
# 14         Berdsk      RU     30.20               smoke  54.76   83.10
# 18    Yellowknife      CA     26.60          light snow  62.46 -114.35
# ..            ...     ...       ...                 ...    ...     ...
# 541        Kijang      KR     53.60       broken clouds  35.24  129.21
# 542      Nevsehir      TR     48.97          few clouds  38.92   34.67
# 546        Iwanai      JP     54.50     overcast clouds  42.97  140.51
# 557       Wiarton      CA     48.99     overcast clouds  44.74  -81.13
# 558         Bayir      TR     51.80           clear sky  37.27   28.22
#
#                                 Hotel Name
# 0    Radisson Blu Polar Hotel, Spitsbergen
# ...

# %%
# Add a heatmap of temperature for the vacation spots and marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# %%
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Add a heatmap of temperature for the vacation spots.
locations = hotel_df[["Lat", "Lng"]]
current_weather = hotel_df["Current Description"]  
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, dissipating=False,
             max_intensity=300, point_radius=4)

marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_vacation.csv"
# Export the City_Data into a CSV.
hotel_df.to_csv(output_data_file,index=False)

# %%
#I want extra credit for creating the pop up marker as instructed in the challenge.  Even though this is not the map that gets submitted
