# %%
# Import the dependencies.
import pandas as pd
import gmaps
import gmaps.datasets
import requests
# Import the API key.
#from config import g_key
from config import g_key2
import traceback

# %%
itn_cities_df = pd.read_csv("weather_data/WeatherPy_vacation.csv")

# %%
pd.set_option('display.max_rows', None)
itn_cities_df
# Out:
#                        City Country  Max Temp      Current Description    Lat  \
# 0              Longyearbyen      SJ     28.40               few clouds  78.22
# 1                Bredasdorp      ZA     50.00            broken clouds -34.53
# 2                   Ushuaia      AR     46.40         scattered clouds -54.80
# 3                    Berdsk      RU     30.20                    smoke  54.76
# 4               Yellowknife      CA     26.60               light snow  62.46
# 5              Punta Arenas      CL     48.20         scattered clouds -53.15
# 6                   Halifax      CA     34.00                     snow  44.65
# 7               New Norfolk      AU     54.00            broken clouds -42.78
# 8                       Ayr      GB     41.00                clear sky  55.46
# 9                Nikolskoye      RU     36.00          overcast clouds  59.70
# 10                    Gavle      SE     39.00               few clouds  60.67
# ...

# %%
tierra1 = itn_cities_df.loc[itn_cities_df["City"] == "Ushuaia"].copy()

# %%
tierra1
# Out:
#       City Country  Max Temp Current Description   Lat   Lng      Hotel Name
# 2  Ushuaia      AR      46.4    scattered clouds -54.8 -68.3  Albatros Hotel

# %%
Ushuaia = tierra1["Lat"][2], tierra1["Lng"][2]

# %%
Ushuaia
# Out:
# (-54.8, -68.3)

# %%
tierra2 = itn_cities_df.loc[itn_cities_df["City"] == "Punta Arenas"].copy()

# %%
tierra2
# Out:
#            City Country  Max Temp Current Description    Lat    Lng  \
# 5  Punta Arenas      CL      48.2    scattered clouds -53.15 -70.92
#
#                   Hotel Name
# 5  Hotel Dreams Del Estrecho

# %%
Punta_Arenas = tierra2["Lat"][5], tierra2["Lng"][5]

# %%
Punta_Arenas
# Out:
# (-53.15, -70.92)

# %%
tierra3 = itn_cities_df.loc[itn_cities_df["City"] == "Coihaique"].copy()
tierra3
# Out:
#          City Country  Max Temp Current Description    Lat    Lng  \
# 90  Coihaique      CL      44.6          light rain -45.58 -72.07
#
#                     Hotel Name
# 90  Diego De Almagro Coyhaique

# %%
Coihaique = tierra3["Lat"][90], tierra3["Lng"][90]

# %%
Coihaique
# Out:
# (-45.58, -72.07)

# %%
tierra4 = itn_cities_df.loc[itn_cities_df["City"] == "Lebu"].copy()

# %%
tierra4
# Out:
#     City Country  Max Temp Current Description    Lat    Lng        Hotel Name
# 22  Lebu      CL     54.84       broken clouds -37.62 -73.65  Hostal Las Lilas

# %%
Lebu = tierra4["Lat"][22], tierra4["Lng"][22]

# %%
Lebu
# Out:
# (-37.62, -73.65)

# %%
#from config import g_key2
#print (g_key2)

# %%
import gmaps
import gmaps.datasets
import requests
# Import the API key.
#from config import g_key2

# Latitude-longitude pairs
Lebu = (-37.62, -73.65)
Coihaique = (-45.58, -72.07)
Punta_Arenas = (-53.15, -70.92)
Ushuaia = (-54.8, -68.3)

#fig = gmaps.figure()
#geneva2zurich = gmaps.directions_layer(geneva, zurich)
#fig.add_layer(geneva2zurich)
#fig

#or
#lebu2ushuaia
gmaps.configure(api_key=g_key2)
fig = gmaps.figure()
lebu2ushuaia = gmaps.directions_layer(
        Lebu, Ushuaia, waypoints=[Coihaique, Punta_Arenas],
        travel_mode='DRIVING',)
fig.add_layer(lebu2ushuaia)
fig

#show_markers=False
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# %%
#itn_cities_df.drop([0:11], axis=0)
drop1 = itn_cities_df.drop(itn_cities_df.index[0:2])

# %%
drop1
# Out:
#                        City Country  Max Temp      Current Description    Lat  \
# 2                   Ushuaia      AR     46.40         scattered clouds -54.80
# 3                    Berdsk      RU     30.20                    smoke  54.76
# 4               Yellowknife      CA     26.60               light snow  62.46
# 5              Punta Arenas      CL     48.20         scattered clouds -53.15
# 6                   Halifax      CA     34.00                     snow  44.65
# 7               New Norfolk      AU     54.00            broken clouds -42.78
# 8                       Ayr      GB     41.00                clear sky  55.46
# 9                Nikolskoye      RU     36.00          overcast clouds  59.70
# 10                    Gavle      SE     39.00               few clouds  60.67
# 11               Baruun-Urt      MN     38.32          overcast clouds  46.68
# 12                   Bulgan      MN     32.86         scattered clouds  48.81
# ...

# %%
drop2 = drop1.drop(itn_cities_df.index[3:5])

# %%
drop2
# Out:
#                        City Country  Max Temp      Current Description    Lat  \
# 2                   Ushuaia      AR     46.40         scattered clouds -54.80
# 5              Punta Arenas      CL     48.20         scattered clouds -53.15
# 6                   Halifax      CA     34.00                     snow  44.65
# 7               New Norfolk      AU     54.00            broken clouds -42.78
# 8                       Ayr      GB     41.00                clear sky  55.46
# 9                Nikolskoye      RU     36.00          overcast clouds  59.70
# 10                    Gavle      SE     39.00               few clouds  60.67
# 11               Baruun-Urt      MN     38.32          overcast clouds  46.68
# 12                   Bulgan      MN     32.86         scattered clouds  48.81
# 13                Jamestown      US     45.00                clear sky  42.10
# 14                  Pastavy      BY     32.32         scattered clouds  55.12
# ...

# %%
drop3 = drop2.drop(itn_cities_df.index[6:22])

# %%
drop3
# Out:
#                        City Country  Max Temp      Current Description    Lat  \
# 2                   Ushuaia      AR     46.40         scattered clouds -54.80
# 5              Punta Arenas      CL     48.20         scattered clouds -53.15
# 22                     Lebu      CL     54.84            broken clouds -37.62
# 23             Bilokurakyne      UA     38.35               few clouds  49.53
# 24                   Sindor      RU     31.17          overcast clouds  62.86
# 25                  Alnashi      RU     33.69         scattered clouds  56.19
# 26           Severo-Kurilsk      RU     34.54               few clouds  50.68
# 27                Lipin Bor      RU     29.01            broken clouds  60.26
# 28             Mastic Beach      US     43.00            broken clouds  40.77
# 29                    Paveh      IR     46.18                clear sky  35.04
# 30            Mount Gambier      AU     48.20          overcast clouds -37.83
# ...

# %%
drop4 = drop3.drop(itn_cities_df.index[23:90])

# %%
drop4
# Out:
#               City Country  Max Temp Current Description    Lat     Lng  \
# 2          Ushuaia      AR     46.40    scattered clouds -54.80  -68.30
# 5     Punta Arenas      CL     48.20    scattered clouds -53.15  -70.92
# 22            Lebu      CL     54.84       broken clouds -37.62  -73.65
# 90       Coihaique      CL     44.60          light rain -45.58  -72.07
# 91            Gari      RU     33.67    scattered clouds  59.43   62.35
# 92          Atyrau      KZ     46.40     overcast clouds  47.12   51.88
# 93         Ivanava      BY     35.40       broken clouds  52.15   25.54
# 94     Great Falls      US     42.01     overcast clouds  47.50 -111.30
# 95            Roma      US     44.60           clear sky  43.21  -75.46
# 96         Sorland      NO     40.77     overcast clouds  67.67   12.69
# 97       Reichenau      PL     46.99     overcast clouds  50.91   14.96
# 98            Nuuk      GL     28.40   light shower snow  64.18  -51.72
# ...

# %%
drop5 = drop4.drop(itn_cities_df.index[91:])

# %%
drop5
# Out:
#             City Country  Max Temp Current Description    Lat    Lng  \
# 2        Ushuaia      AR     46.40    scattered clouds -54.80 -68.30
# 5   Punta Arenas      CL     48.20    scattered clouds -53.15 -70.92
# 22          Lebu      CL     54.84       broken clouds -37.62 -73.65
# 90     Coihaique      CL     44.60          light rain -45.58 -72.07
#
#                     Hotel Name
# 2               Albatros Hotel
# 5    Hotel Dreams Del Estrecho
# 22            Hostal Las Lilas
# 90  Diego De Almagro Coyhaique

# %%
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in drop5.iterrows()]

# %%
locations = drop5[["Lat", "Lng"]]
current_weather = drop5["Current Description"]  

marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)

fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
